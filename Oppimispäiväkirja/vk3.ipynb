# %% [markdown]
# # Oppimispäiväkirja - Viikko 3
#
# Tämän viikon luennolla oli niin laidasta laitaan mielenkiintoisia aiheita sosiaalisen median analyysistä ja piirteistä luonnollisen kielen analyysiin, että oppimispäiväkirjan pitäminen ohjepituudessa voi tuottaa hankaluuksia. Tässä siis hyvin rankalla kädellä tiivistettynä tämän viikon ajatuksia.
#
# Olen jo aiemmin ymmärtänyt mallintamisen perusperiaatteen: opetetaan jollain datalla malli, testataan mallin toimivuutta toisella aineistolla ja sopivan mallin löydyttyä siirretään malli tuotantokäyttöön. En ole aiemmin tullut ajatelleeksi (vaikka olisi varmaan pitänyt olla itsestäänselvää), että olemassa olevan aineiston voi jakaa opetusdataan ja testidataan, jolloin testidatasta voidaan suoraan katsoa, kuinka tarkka malli ja sen tekemät ennusteet ovat.
#
# Poistuma-analyysi oli myös mielenkiinoinen uusi tuttavuus. Kilpailu asiakkaista on kovaa monella eri alalla, ja muistan lukeneeni että yrityksille on todella paljon kalliimpaa hankkia uusi asiakas kuin ylläpitää vanhaa. Mielestäni artikkelissa oli myös hyvin perusteltu ja laskettu tuotto poistuma-analyysille. Yksi kohta pisti myös erityisesti silmään:
#
# *"Monilta yrityksiltä ei löydy kaikkia näitä tietoja, olen nähnyt yrityksiä joilla asiakkaista tiedetään käytännössä vain numero ja osoite. Ei edes nimeä tai sitä onko kyseessä yritys- vai henkilöasiakas. Ennen kuin analytiikkaa päästään hyödyntämään täysillä, on edessä usein systemaattinen tiedon keräämisvaihe ja mahdollisesti muutokset lähdejärjestelmiin/tietovarastoon."*
#
# Minusta tuntuu, että tämä teema ja oivallus toistuu viikosta toiseen. Jossain yrityksissä halutaan hyödyntää analytiikkaa, mutta samaan aikaan voi olla, että perusasiat datan keräyksessä ei ole kunnossa. Tällöin data-analytiikkaa on mahdotonta lähteä tekemään, vaan aika menee datan keräämiseen ja esivalmisteluun.
#
# Mielestäni on myös todella tärkeää huomioida tuo, että analyysien pitää aina johtaa toimintaan ja sen pitää tuottaa tulosta. Analyysiä ei tulisi koskaan tehdä vain analyysien ilosta. Olen ennen tätä kurssia myös ajatellut, että liiketoimintatiedon hallinta (*engl. business intelligence*) ja data-analytiikka olisi jollain tavalla sama asia, mutta viimeistään nyt on käynyt selväksi, että ne eivät ole.
#
# ### Tärkeimmät opit
# 1. Sosiaalisesta mediasta, kuten esimerkiksi twitteristä, saa tehtyä todella monipuolisia analyysejä perinteisten retweettauksien tai tykkäysten määrän lisäksi.
# 2. Poistuma-analyysi on ns. "helppo ja halpa" eli suhteellisen yksinkertainen toteuttaa verrattuna siitä saatuihin hyötyihin.
# 3. Analyysien tulee aina johtaa toimintaan ja tuottaa tulosta.
# 4. NLP analyysin tekeminen.
# 5. Lineaarisen regression tekeminen
#
# ### Risut ja ruusut luentoviikolle
# + Mielestäni tämä luentokerta oli loogisemmin rakennettu ja sitä oli helpompi seurata.
# + Käsiteltävät aiheet ovat todella mielenkiintoisia (niin mielenkiintoisia, että oppimispäiväkirjan pituudessa tulee puolen luennon jälkeen helposti raja vastaan).
# + On hyvä, että annetaan paljon hyviä artikkeleita luettavaksi aiheisiin liittyen, ja että luentojen materiaalit ovat hyvin monipuolisia. Tämä on erityisen hyvää vaihtelua muuhun yliopiston opetukseen nähden, mistä opiskelijoille jää helposti sellainen ajatus että vain akateemiset artikkelit ovat relevantteja lähteitä. Tietoa löytyy internetistä loputtomiin ja sitä tulisi osata hyödyntää mahdollisimman tehokkaasti.
# + Tykkään myös siitä, että tällä kurssilla lähestyminen on pääosin optimistista.
#
# ### Kehitysehdotukset
# - Luennolla nostettiin esille jonkilaiset esitehtävät. Tuli mieleen, olisiko kurssilla mahdollista olla jonkinlaisia pienimuotoisia viikkotehtäviä/-harjoituksia joka viikon aiheeseen liittyen. Esimerkiksi datan siivoamiseen tms. Näiden avulla opittu konkretisoituisi, ja toisaalta harjoitustyön suoritus helpottuisi. Koska harjoitustyöhön on annettu aika vapaat kädet, olisi hyvä että jokin osuus kurssista olisi ns. kaikille yhteinen. Datatiede on kuitenkin paljon hands on -tyyppistä tekemistä, joten mitä enemmän asioita pääsee itse konkreettisesti tekemään, sitä paremmin oppii.
#
# *(Katsoin molemmat opetustapahtumat tallenteina. Aineistona käytetty luentoa, luentomuistiota liitteineen ja koodiklinikkaa. Koodiesimerkin data haettu Kagglesta.)*

# %%
# !pip install sklearn
# !pip install numpy
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\jenna.rajala\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\jenna.rajala\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
# Koodiesimerkki - vk3

# Koska tämän viikon koodiklinikan esimerkki oli niin mielenkiintoinen, käytän sitä myös tässä koodiesimerkkinä.

# Haetaan tarvittavat kirjastot
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from sklearn.impute import SimpleImputer as Imputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.svm import SVC

from warnings import filterwarnings 
filterwarnings('ignore')

# %%
df = pd.read_csv("credit_train.csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %%
cols_to_remove = ['Loan ID', 'Customer ID']
data = df.drop(cols_to_remove, axis=1)

# %%
# Korvaa tyhjät arvot sarakkeen keskiarvolla
cols_to_clean = ['Current Loan Amount', 'Credit Score', 'Annual Income', 'Years of Credit History', 'Months since last delinquent', 'Number of Open Accounts', 'Number of Credit Problems', 'Current Credit Balance', 'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'] 

imputer = Imputer()
data[cols_to_clean] = imputer.fit_transform(data[cols_to_clean])
data[cols_to_clean] = data[cols_to_clean].astype(int)

# Poistaa tyhjät rivit
data= data.dropna()

# %%
# Muutetaan tarkasteltava arvo numeerisiksi arvoiksi
y = []
for i in data['Loan Status']:
    if i == 'Fully Paid':
        y.append(1)
    else:
        y.append(0)
        
data = data.drop('Loan Status', axis=1)

# %%
# Muutetaan kategoriset muuttujat numeerisiksi

print(data.info())
data = pd.get_dummies(data)
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95778 entries, 0 to 99998
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Current Loan Amount           95778 non-null  int32
#  1   Term                          95778 non-null  object
#  2   Credit Score                  95778 non-null  int32
#  3   Annual Income                 95778 non-null  int32
#  4   Years in current job          95778 non-null  object
#  5   Home Ownership                95778 non-null  object
#  6   Purpose                       95778 non-null  object
#  7   Monthly Debt                  95778 non-null  float64
#  8   Years of Credit History       95778 non-null  int32
#  9   Months since last delinquent  95778 non-null  int32
#  10  Number of Open Accounts       95778 non-null  int32
#  11  Number of Credit Problems     95778 non-null  int32
# ...

# %%
# Datan normalisointi

xMean = np.mean(data, axis=0)
xDev = np.std(data, axis=0)
xNorm = (data - xMean) / xDev

x = data.values 
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
xMinMax = pd.DataFrame(x_scaled)
XNoNorm = data

# %%
xNorm
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 0                -0.357163     -0.275813      -0.231181     -1.102757
# 1                -0.362911      0.002478      -0.017082      1.193086
# 2                 2.768168     -0.251548       0.849964      0.858254
# 3                -0.360232     -0.266714      -0.597397     -0.814386
# 4                -0.365614      0.002478      -0.017082      0.158344
# ...                    ...           ...            ...           ...
# 99994            -0.364535     -0.268230      -0.621328     -1.224340
# 99995            -0.366529     -0.263681      -0.934125     -1.348999
# 99996             2.768168     -0.258373      -0.107340     -0.457340
# 99997            -0.367908     -0.250790      -0.248396     -0.930999
# 99998            -0.354497     -0.247757       0.327503     -0.720515
#
#        Years of Credit History  Months since last delinquent  \
# 0                    -0.083655                     -0.025223
# ...

# %%
data_versions = []

# Määritellään kolme tapausta tarkasteltavaksi
for x in [xNorm, xMinMax, XNoNorm]:
    version = {}
    version['x_train'], version['x_test'], version['y_train'], version['y_test'] = train_test_split(x, y, test_size= 0.25, random_state=13)
    data_versions.append(version)

# %%
# Luokittelijat
classifiers = [SGDClassifier(), LogisticRegression()]

for i, data_version in enumerate(data_versions):
    print("Evaluating the models with data from the version #{}".format(i+1))
    for j, clf in enumerate(classifiers):
        clf.fit(X=data_version['x_train'], y=data_version['y_train'])
        predictions = clf.predict(X=data_version['x_test'])
        accuracy = accuracy_score(data_version['y_test'], predictions)
        print("\t Classifier #{} achieved {} accuracy on test data.".format(j+1, accuracy))
# Out:
# Evaluating the models with data from the version #1
# 	 Classifier #1 achieved 0.8182501566088954 accuracy on test data.
# 	 Classifier #2 achieved 0.8202965128419294 accuracy on test data.
# Evaluating the models with data from the version #2
# 	 Classifier #1 achieved 0.8204217999582376 accuracy on test data.
# 	 Classifier #2 achieved 0.8205053247024431 accuracy on test data.
# Evaluating the models with data from the version #3
# 	 Classifier #1 achieved 0.71129672165379 accuracy on test data.
# 	 Classifier #2 achieved 0.8174984339110462 accuracy on test data.

# %%
# Implement Cross Validation using Logistic Regression classifier
# Using xMinMax dataframe

clf = LogisticRegression()
scores = cross_val_score(clf, xMinMax, y, verbose=1, cv=5)
print(scores)
print("Accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() *2))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [0.82355398 0.81817707 0.82162247 0.82281389 0.82333594]
# Accuracy: 0.822 (+/- 0.004)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.1s finished
